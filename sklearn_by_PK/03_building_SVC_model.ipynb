# %% [markdown]
# # Data Ref:
#
# https://www.kaggle.com/datasets/dongeorge/seed-from-uci
#
# Download wheat-dataset from above link.
# We'll implement a model to predict the type of wheat.

# %%
import pandas as pd
total_data=pd.read_csv("data_03/Seed_Data.csv")
total_data.describe
# Out:
# <bound method NDFrame.describe of          A      P       C     LK     WK  A_Coef    LKG  target
# 0    15.26  14.84  0.8710  5.763  3.312   2.221  5.220       0
# 1    14.88  14.57  0.8811  5.554  3.333   1.018  4.956       0
# 2    14.29  14.09  0.9050  5.291  3.337   2.699  4.825       0
# 3    13.84  13.94  0.8955  5.324  3.379   2.259  4.805       0
# 4    16.14  14.99  0.9034  5.658  3.562   1.355  5.175       0
# ..     ...    ...     ...    ...    ...     ...    ...     ...
# 205  12.19  13.20  0.8783  5.137  2.981   3.631  4.870       2
# 206  11.23  12.88  0.8511  5.140  2.795   4.325  5.003       2
# 207  13.20  13.66  0.8883  5.236  3.232   8.315  5.056       2
# 208  11.84  13.21  0.8521  5.175  2.836   3.598  5.044       2
# 209  12.30  13.34  0.8684  5.243  2.974   5.637  5.063       2
#
# [210 rows x 8 columns]>

# %%
X = total_data.iloc[:,:-1]
X
# Out:
#          A      P       C     LK     WK  A_Coef    LKG
# 0    15.26  14.84  0.8710  5.763  3.312   2.221  5.220
# 1    14.88  14.57  0.8811  5.554  3.333   1.018  4.956
# 2    14.29  14.09  0.9050  5.291  3.337   2.699  4.825
# 3    13.84  13.94  0.8955  5.324  3.379   2.259  4.805
# 4    16.14  14.99  0.9034  5.658  3.562   1.355  5.175
# ..     ...    ...     ...    ...    ...     ...    ...
# 205  12.19  13.20  0.8783  5.137  2.981   3.631  4.870
# 206  11.23  12.88  0.8511  5.140  2.795   4.325  5.003
# 207  13.20  13.66  0.8883  5.236  3.232   8.315  5.056
# 208  11.84  13.21  0.8521  5.175  2.836   3.598  5.044
# 209  12.30  13.34  0.8684  5.243  2.974   5.637  5.063
#
# [210 rows x 7 columns]

# %%
y=total_data.iloc[:,-1]
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 205    2
# 206    2
# 207    2
# 208    2
# 209    2
# Name: target, Length: 210, dtype: int64

# %%
import sklearn
from sklearn import svm
from sklearn.svm import SVC

# %%
# learning a model
from sklearn.model_selection import train_test_split
# by default the data is split in 3:1 ratio for train:test

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=13)
# test_size: test data = 20%
# random_state: any number (as a seed to random number generator)

# normalising data:
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)
[X_train,X_test]
# Out:
# [array([[ 1.48368442,  1.60267517, -0.11991681, ...,  0.81343913,
#          -0.9937377 ,  2.19083249],
#         [ 0.34613237,  0.29257419,  0.89555987, ...,  0.48882981,
#           1.24345987, -0.52885215],
#         [ 1.42325197,  1.38169428,  0.82241113, ...,  1.20131976,
#          -0.28476207,  1.3648083 ],
#         ...,
#         [ 0.71583679,  0.76610466,  0.30606705, ...,  0.63187798,
#           0.21275331,  0.92701548],
#         [-1.26065989, -1.20693899, -1.54846876, ..., -1.50284095,
#           1.0761079 , -0.61971481],
#         [ 1.91737613,  1.85522476,  0.77077672, ...,  1.67172818,
#           0.97102642,  1.6415264 ]]),
#  array([[ 1.67209147e+00,  1.71316562e+00,  2.80249847e-01,
#           1.72946524e+00,  1.49841982e+00, -4.63141119e-01,
#           1.63739628e+00],
#         [ 1.90315673e+00,  1.96571520e+00,  8.66208171e-02,
#           2.07083544e+00,  1.42139388e+00, -1.14552206e+00,
#           1.63739628e+00],
# ...

# %%
clf=SVC()
clf.fit(X_train,y_train)

pred_clf = clf.predict(X_test)
sklearn.metrics.accuracy_score(y_test,pred_clf)
# Out:
# 0.9523809523809523

# %%
print(sklearn.metrics.classification_report(y_test,pred_clf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         8
#            1       1.00      0.95      0.97        19
#            2       1.00      0.93      0.97        15
#
#     accuracy                           0.95        42
#    macro avg       0.93      0.96      0.94        42
# weighted avg       0.96      0.95      0.95        42
