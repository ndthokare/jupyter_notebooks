# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6]
y = [23,43,26,32,44,35]

plt.xlabel('Day')
plt.ylabel('Temperarture')
plt.title('Weather')
plt.plot(x,y,color="deeppink",linewidth=5, linestyle='dashdot')
