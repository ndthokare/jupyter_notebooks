# %% [markdown]
# <h1 align="center", style="color:green">Matplotlib Tutorial: Histogram</h1>

# %% [markdown]
# **In histograms, x axis contains a variable and y axis will be a frequency of that variable**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# We have a sample data of blood sugar level of different patients, we will try to plot number of patients by blood range and try to figure out how many patients are normal, pre-diabetic and diabetic

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar, rwidth=0.8) # by default number of bins is set to 10
# rwidth: Relative width compared to the bin size
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(blood_sugar, rwidth=0.8, bins=15)
# Out:
# (array([2., 2., 2., 1., 0., 0., 0., 2., 0., 0., 1., 1., 0., 0., 2.]),
#  array([ 77.        ,  81.86666667,  86.73333333,  91.6       ,
#          96.46666667, 101.33333333, 106.2       , 111.06666667,
#         115.93333333, 120.8       , 125.66666667, 130.53333333,
#         135.4       , 140.26666667, 145.13333333, 150.        ]),
#  <BarContainer object of 15 artists>)

# %%
plt.hist(blood_sugar, rwidth=0.8, bins=3)
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(blood_sugar, rwidth=0.8, bins=[80,100,125,180], color="green")
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 180]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(blood_sugar, rwidth=0.95, bins=[80,100,125,180], color="g", histtype='step')
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 180]),
#  [<matplotlib.patches.Polygon at 0x2acbd3f88e0>])

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]


plt.hist([blood_sugar_men, blood_sugar_women], rwidth=0.8, 
         bins=[80,100,125,150], color=["green","orange"], 
         label=["men","women"])
plt.legend()

# %% [markdown]
# # Horizontal orientation:

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]


plt.hist([blood_sugar_men, blood_sugar_women], rwidth=0.8, 
         bins=[80,100,125,150], color=["green","orange"], 
         label=["men","women"], orientation="horizontal")
plt.legend()
